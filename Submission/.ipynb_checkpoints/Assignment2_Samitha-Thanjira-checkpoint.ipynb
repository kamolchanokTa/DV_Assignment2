# %% [markdown]
# # Data Visualization (2017/18)
#
# ## Solutions for Assignment 2 - Exploratory Data Analysis
#
# Presented by Group 18:
# - Samitha Jayathilake
# - Thanjira Amornkosit
#
# Date: 17.11.2017
#
# Hints:
# - Double click on a cell to edit it.
# - Enter the Markdown mode in the drop-down menu above (it may say Code for new cells).
# - Run a cell by pressing CTRL+Enter
# - Markdown docu: http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
# - Markdown cheatsheet: http://datascience.ibm.com/blog/markdown-for-jupyter-notebooks-cheatsheet/

# %% [markdown]
# ### Exercise 1: Choose a data set
#
# We will use the Python Data Analysis Library (Pandas) to work with the data. Pandas provides a rich feature set for working with tabular data including data structures and analysis tools.
#
# A 10 minute introduction to pandas with all neccessary functions can be found here: http://pandas.pydata.org/pandas-docs/stable/10min.html (Quickly skim over the available functionality. You don't have to learn it yet.)

# %%
# import the pandas library and call it pd for further usage
import pandas as pd

# %% [markdown]
# #### Sample code to load the baseball data and get basic statistics

# %%
# read the csv file into a pandas dataframe and print the first lines of the table
filename = "baseball_data.csv"
df = pd.read_csv( filename, header=0 )
df.head()
# Out:
#              name handedness  height  weight    avg   HR
# 0       Tom Brown          R      73     170  0.000    0
# 1  Denny Lemaster          R      73     182  0.130    4
# 2       Joe Nolan          L      71     175  0.263   27
# 3     Denny Doyle          L      69     175  0.250   16
# 4   Jose Cardenal          R      70     150  0.275  138

# %%
df.describe(include="all")
# Out:
#                   name handedness       height       weight          avg  \
# count             1157       1157  1157.000000  1157.000000  1157.000000
# unique            1151          3          NaN          NaN          NaN
# top     Bobby Mitchell          R          NaN          NaN          NaN
# freq                 2        737          NaN          NaN          NaN
# mean               NaN        NaN    72.756266   184.513397     0.186793
# std                NaN        NaN     2.142272    15.445995     0.106175
# min                NaN        NaN    65.000000   140.000000     0.000000
# 25%                NaN        NaN    71.000000   175.000000     0.138000
# 50%                NaN        NaN    73.000000   185.000000     0.238000
# 75%                NaN        NaN    74.000000   195.000000     0.258000
# max                NaN        NaN    80.000000   245.000000     0.328000
#
#                  HR
# count   1157.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean      45.359551
# std       74.065110
# min        0.000000
# 25%        1.000000
# 50%       15.000000
# 75%       55.000000
# max      563.000000

# %% [markdown]
# #### Sample code to load the Titanic data and get basic statistics

# %%
# read the csv file into a pandas dataframe and print the first lines of the table
filename = "titanic3.csv"
df = pd.read_csv( filename, header=0 )
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df.describe(include="all")
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881138
# std        0.837836     0.486055                   NaN   NaN    14.413493
# min        1.000000     0.000000                   NaN   NaN     0.170000
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# count   1309.000000  1309.000000      1309  1308.000000          295     1307
# unique          NaN          NaN       929          NaN          186        3
# top             NaN          NaN  CA. 2343          NaN  C23 C25 C27        S
# freq            NaN          NaN        11          NaN            6      914
# mean       0.498854     0.385027       NaN    33.295479          NaN      NaN
# std        1.041658     0.865560       NaN    51.758668          NaN      NaN
# min        0.000000     0.000000       NaN     0.000000          NaN      NaN
# 25%        0.000000     0.000000       NaN     7.895800          NaN      NaN
# 50%        0.000000     0.000000       NaN    14.454200          NaN      NaN
# 75%        1.000000     0.000000       NaN    31.275000          NaN      NaN
# max        8.000000     9.000000       NaN   512.329200          NaN      NaN
#
#        boat        body     home.dest
# count   486  121.000000           745
# unique   27         NaN           369
# top      13         NaN  New York, NY
# freq     39         NaN            64
# mean    NaN  160.809917           NaN
# std     NaN   97.696922           NaN
# min     NaN    1.000000           NaN
# 25%     NaN   72.000000           NaN
# 50%     NaN  155.000000           NaN
# 75%     NaN  256.000000           NaN
# max     NaN  328.000000           NaN

# %% [markdown]
# #### Your selection:
# Selected dataset: Baseball data

# %% [markdown]
# ### Exercise 2: Data queries

# %% [markdown]
# 1. What is the dominant handedness among baseball players?
# 2. What is the average of the batting averages by handedness?
# 3. Does the height affect the batting average?
# 4. Does the batting average correlate to the number of home runs?
# 5. What is the average height and weight of successful baseball players (hit more than 200 home runs)?
# 6. Who are the top ten best baseball players judging from the average batting and the number of home runs?

# %% [markdown]
# ### Exercise 3: Data analysis
#
# Here is sample code to pass your data from the pandas data frame to bokeh and render a graphic inside the notebook.

# %%
filename = "baseball_data.csv"
df = pd.read_csv( filename, header=0 )

# %%
# import bokeh 
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource

# tell bokeh to show the figures in the notebook
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="894535e4-6c6f-40ee-9a5a-da7aa3679e42">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## __ Q1: What is the dominant handedness of baseball players?__
#
# To represent this data we are showing a pie chart. The handedness values, left, right and both are identified and their count is calculated from the data. From this count we can generate a pie chart.

# %%
#Q1: What is the dominant handedness of baseball players?

# compute a histogram of the handedness variable
df_handedness = df['handedness'].value_counts().reset_index()
# set column names
df_handedness.columns = ['height', 'count']
df_handedness.head()
# Out:
#   height  count
# 0      R    737
# 1      L    316
# 2      B    104

# %%
#Q1: Contd.

# display pie chart of handedness
import matplotlib.pyplot as plt

#For labels
handedness_labels = ['Right','Left','Both']

plt.figure(figsize=(4, 4))

colors = ['#e34a33','#fdbb84','#fee8c8']

#draw pie chart
plt.pie(df_handedness['count'], labels=handedness_labels, colors=colors,
        autopct='%1.1f%%', startangle=90)
plt.title('Handedness count of baseball players', y=1.1)
plt.axis('equal')
plt.show()

# %% [markdown]
# From the pie chart we can see that the dominant hand is Right-Handedness at 63.7%. The number of right handed players are more than twice the number of left handed players. Players who are ambidexterous are also significant at 9%.

# %% [markdown]
# ## __ Q2: What is the average of the batting averages by handedness?__
# We decided to use a bar chart to show the mean of batting averages grouped by handedness.

# %%
#Q2: What is the average of the batting averages by handedness?
import numpy as np
from bokeh.io import show
from bokeh.plotting import figure

# x-axis: handedness
handedness = ['Both','Left','Right']

# y-axis: avg - mean of average batting
mean_avg = df.groupby('handedness').mean()['avg']

colors = ['#fee8c8','#fdbb84','#e34a33']
q2 = figure(x_range=handedness, y_range=(0,0.23), plot_width = 400, plot_height=300, 
            x_axis_label= "Handedness", y_axis_label="Average batting",
            title="Average of Batting Average")
q2.vbar(x=handedness, top=mean_avg, width=0.4, color=colors)

# to make the x-grid invisible
q2.xgrid.grid_line_color = None

show(q2)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a7e4c75d-d053-43c1-82f3-b824e721ebf9"></div>
# </div>

# %% [markdown]
# This bar chart shows the mean of batting average grouped by handedness. We can see that the mean of batting average among the players who are left-handed and both-handed is almost similar. However, the mean among the players who are right-handed is slightly lower than the other two groups although they are the majority of baseball players in this study (based on the finding in Q2.)

# %% [markdown]
# ## __ Q3: How does the height of a baseball player affect his batting average?__
#
# For this query we will look at the heights of the players and their respective batting averages by drawing a scatter plot. We try to see how the height of players affect the performance indicated by their batting averages. Additionally we will identify the height of the player with the highest batting average.

# %%
#Q4: Does the batting average correlate to the number of home runs?
from bokeh.models import LinearAxis, Range1d

# x-axis: avg - batting average
df_avg = df['avg']

# y-axis: HR - number of home runs
df_hr = df['HR']

q3 = figure(plot_width=800, plot_height=600, x_axis_label= "Batting average", y_axis_label="# Home runs",
           title="Relationship between batting average and the number of home runs")

# add a circle renderer with a size, color, and alpha
q3.circle(df_avg, df_hr, size=5, color="navy", alpha=0.3)

#hightlight the best batting averages 
best_box = BoxAnnotation(plot=q3, bottom=200, left=0.2, right= 0.31, fill_alpha=0.25, fill_color='yellow')
q3.renderers.extend([best_box])

# show the results
show(q3)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1df177f5-7fd8-4220-99b3-0d0448e78008"></div>
# </div>

# %% [markdown]
# From the scatter plot, we can see that most baseball players have batting average between 0.21 and 0.28. (The mean of batting average is 0.19.) However, we do not see any correlation between batting average and the number of home runs. It is noticeable that most players who have larger number of home runs (more than 200) are usually have batting average between 0.25 and 0.3 which is higher than the mean of batting average.
#
# Although batting average is a performance indicator, it does not determine the number of home runs. In other words, it cannot be concluded that the players who have higher batting average will always have higher change of hitting a home run.

# %% [markdown]
# ## __ Q4: Does the batting average correlate to the number of home runs?__
#
# In order to identify the correlation between batting average and the number of home runs. We decided to use a scatter plot.

# %%
# Q4: Does the height of a baseball player affect his batting average
from bokeh.models import BoxAnnotation, Span

#x-axis: height of players
df_heights = df['height']

#y-axis: batting averages
df_batting_avg = df['avg']

q4 = figure(plot_width=650, plot_height=400, x_axis_label= "Player heights (inches)", y_axis_label="Batting average",
           title="Batting average distribution with player heights")

# circles for the distribution
q4.circle(df_heights, df_batting_avg, size=6, color="navy", alpha=0.5)
q4.xaxis[0].ticker.desired_num_ticks = 15

#highest batting average
highest_avg = df['avg'].max()
q4.circle(72, highest_avg, size=6, color="red")

#hightlight the best batting averages 
best_box = BoxAnnotation(plot=q4, bottom=0.3, left=69, right=75, fill_alpha=0.25, fill_color='yellow')

#line for height mean
vline = Span(location=72.756266, dimension='height', line_color='red', line_width=1)

q4.renderers.extend([best_box, vline])

# show the results
show(q4)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6edbb833-a59e-48d9-87d8-72482b075b56"></div>
# </div>

# %% [markdown]
# With this scatter plot of the batting averages with the player heights, we can see that the batting averages are high (more than 0.3) for the height range between 69 and 75 inches (highlighted in yellow area). The player with highest batting average has a height of 72 inches (shown as a red dot). If we consider the mean of heights, 72.756266, players with heights close to this mean
# usually have high batting averages.
#
# In the next bar chart we look at how the batting average mean is distributed with the player heights.

# %%
# Q4: Contd.

#average batting averages grouped by height
mean_avg_by_height = df.groupby('height').mean()['avg']
df_height_meanavg = mean_avg_by_height.reset_index()

q4 = figure(x_range=(64, 81), y_range=(0,0.3), plot_width = 600, plot_height=400, 
            x_axis_label= "Player heights", y_axis_label="Mean Batting average",
            title="Average of Batting Average over height")
q4.vbar(x=df_height_meanavg['height'], top=mean_avg_by_height, width=0.4)

#increase x axis ticks
q4.xaxis[0].ticker.desired_num_ticks = 15

show(q4)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6b44e2f8-e40f-438b-bd2f-577cd385a28a"></div>
# </div>

# %% [markdown]
# This chart is left skewed indicating that the mean of batting average is higher for shorter players. Specifically, the player height 67 has a mean batting average of 0.263250. And there is a decline of batting averages with the increase of height.
#
# However, This can be attributed to the fact of having a smaller number of short players. Nonetheless, even those amount of players have managed to get a high batting average among themselves. Even in the scatter plot we see that the players shorter than 69 have managed to keep a non-zero batting average.

# %% [markdown]
# ## __ Q5: What is the average height and weight of the successful baseball players (hit more than 200 home runs)?__
# We used a scatter plot to show the height and weight of baseball players who have hit more than 200 home runs. The average height and weight of these players is represented by a red dot.

# %%
#Q5: What is the average height and weight of the successful baseball players (hit more than 100 home runs)?

# x-axis: avg - batting average
weight = df['weight']

# y-axis: HR - number of home runs
height = df['height']

q5 = figure(plot_width=550, plot_height=300, x_axis_label= "Weight (pounds)", y_axis_label="Height (inches)", 
            title="Height and weight of baseball players who hit more than 200 home runs")

# add a circle renderer with a size, color, and alpha
q5.circle(weight, height, size=7, color="navy", alpha=0.5)

# find mean
q5_df_mean = df.loc[df['HR'] > 200].mean()
q5.circle(q5_df_mean['weight'], q5_df_mean['height'], size=7, color="red")

# show the results
show(q5)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="87c87162-7926-4fe0-8081-c22ef74f71ee"></div>
# </div>

# %% [markdown]
# In this scatter plot, we can see the weight and height of baseball players who hit more than 200 home runs. Each dot represents a baseball player weight (x-axis) and height (y-axis). The average weight and height is represented by a red dot at 190.78 pounds and 73.15 inches.
#
# We also found that the mean weight and height of baseball players who have hit more than 200 home runs is higher than the mean weight and height of all baseball players in this dataset at 184.51 pounds and 72.76	inches respectively.

# %% [markdown]
# ## __ Q6: Who are the top 10 best baseball players considering batting average and number of Homeruns?__
#
# We first looked at the top 10 players according to batting average. The data is sorted with descending order of batting average and the top 10 players are filtered. Their number of Homeruns are also displayed.

# %%
#Q6: Who are the top 10 baseball players considering batting average and number of Homeruns?

#top 10 by batting average
sorted_avg = df.sort_values(by='avg', ascending=False)
top_10_avg = sorted_avg.loc[:,['name', 'avg', 'HR']][0:10]
top_10_avg
# Out:
#               name    avg   HR
# 281      Rod Carew  0.328   92
# 861  Lyman Bostock  0.311   23
# 547     Matty Alou  0.307   31
# 934     Ralph Garr  0.306   75
# 792   Bill Madlock  0.305  163
# 154     Tony Oliva  0.304  220
# 835     Manny Mota  0.304   31
# 357      Al Oliver  0.303  219
# 24       Pete Rose  0.303  160
# 484   Bake McBride  0.299   63

# %% [markdown]
# Then we look at the top 10 players according to number of homeruns. The data is sorted with descending order of number of homeruns and the top 10 players are filtered. Their batting average is also on display.

# %%
#Q6: Contd.

#top 10 by number of Homeruns
sorted_hr = df.sort_values(by='HR', ascending=False)
top_10_hr = sorted_hr.loc[:,['name', 'HR', 'avg']][0:10]
top_10_hr
# Out:
#                   name   HR    avg
# 656     Reggie Jackson  563  0.262
# 995       Mike Schmidt  548  0.267
# 972    Willie Stargell  475  0.282
# 422   Carl Yastrzemski  452  0.285
# 45        Dave Kingman  442  0.236
# 16       Darrell Evans  414  0.248
# 295      Graig Nettles  390  0.248
# 761       Johnny Bench  389  0.267
# 1052          Jim Rice  382  0.298
# 203         Tony Perez  379  0.279

# %% [markdown]
# Next we will try to create a scatter plot to find if there is any correlation between the top 10 players by batting average and by the number of home runs. From the above tables we already see that these dimensions are completely disjoint. We will try to see if this can be shown with the next scatter plot. For this we will focus on the batting averages above 0.23, because the lowest batting average for top number of homeruns is 0.236. Then we mark the top 10 batting averages and the top 10 number of homeruns. To find if there is any intersection between the two, we will mark the areas in the chart corresponding with the top 10 values of both dimensions.

# %%
#Q6: Contd.
from bokeh.models import Legend, Label

#batting averages above 0.23, because top home runs have lovest batting average of 0.236
df_avg_above_23 = df.loc[df['avg'] > 0.23]

q6 = figure(plot_width=900, plot_height=500, x_axis_label= "Batting average", y_axis_label="# Home runs",
           title="Above 0.23 batting average with number of home runs")

# add a circle renderer with a size, color, and alpha
q6.circle(df_avg_above_23['avg'], df_avg_above_23['HR'], size=5, color="navy", alpha=0.2)

# add circles for the top 10 number of homeruns
c1 = q6.circle(top_10_hr['avg'], top_10_hr['HR'], size=5, color="maroon", alpha=0.8)

#add circles for the top 10 batting average
c2 = q6.circle(top_10_avg['avg'], top_10_avg['HR'], size=5, color="green", alpha=0.8)

q6.xaxis[0].ticker.desired_num_ticks = 20

legend = Legend(items=[
    ("Top 10 # of homeruns",   [c1]),
    ("Top 10 batting averages", [c2])
], location=(0, 200))



#hightlight the best batting averages 
best_avg_box = BoxAnnotation(plot=q6, left=0.299, fill_alpha=0.15, fill_color='yellow')
#highlight best homeruns
best_hr_box = BoxAnnotation(plot=q6, bottom = 379, fill_alpha=0.15, fill_color='yellow')
q6.renderers.extend([best_avg_box, best_hr_box])

label = Label(x=0.298, y=382, text='Jim Rice')
q6.add_layout(label)
q6.add_layout(legend, 'left')

# show the results
show(q6)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ef32dc3f-cba7-46d2-93b5-adaab66a41e4"></div>
# </div>

# %% [markdown]
# From this chart we see that the top 10 batting averages and top 10 number of homeruns are disjoint. the intersection area does not contain any value. So it is difficult to determine the overall top 10 players with respecto to both the batting average and the number of homeruns. But we can approximate that one player, Jim Rice is close to the intersection, which means he has a high batting average with a high number of homeruns.
